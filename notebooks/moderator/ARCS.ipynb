# %%
# some goodies
# %matplotlib notebook
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

# %%
from snschops.moderator import arcs_model as arcs

# %% [markdown]
# ## I(E)

# %%
E1 = np.arange(0, 0.001, 1e-5)
E2 = np.arange(0.001, 1, 1e-3)
E = np.concatenate((E1, E2))
I = arcs.model.I_E(E)

# %%
plt.figure()
plt.title("I(E)")
plt.xlabel('Energy (eV)')
plt.plot(E,I)

# %%
plt.figure()
plt.title("I(E)")
plt.xlabel('Energy (eV)')
plt.loglog(E,I)

# %% [markdown]
# ## I(t) - Ikeda-Carpenter function

# %%
E = 100 #meV

# %%
I_t = arcs.model.IC_atE(E/1e3)

# %%
t = np.arange(0,200, 0.1)
I = I_t(t)
plt.figure()
plt.title("I(t)")
plt.xlabel('t (microsecond)')
plt.plot(t,I)

# %%
plt.figure()
plt.title("I(t)")
plt.xlabel('t (microsecond)')
plt.semilogy(t,I)

# %% [markdown]
# ## I(t) through Fermi chopper

# %%
t = np.arange(0, 200., .1)
t0 = 10.
from snschops.moderator.fermichopper import FermiChopper as base
class FC(base):
    frequency = 600 #Hz
    slit_thickness = 1.5 #mm
    radius = 50 #mm
I = arcs.model.time_distrib_thru_fc(t, t0, E/1e3, FC())
plt.figure()
plt.title("I(t)")
plt.xlabel('t (microsecond)')
plt.plot(t,I)

# %%
plt.figure()
plt.title("I(t)")
plt.xlabel('t (microsecond)')
plt.semilogy(t,I)

# %%
fc = FC()

# %%
fc.delta_t()
# Out:
# 7.957747154594767
